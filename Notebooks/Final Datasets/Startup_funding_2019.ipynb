# %%
import numpy as np
import pandas as pd

# %%
# display table

sf_19= pd.read_csv('startup_funding2019.csv')
sf_19
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# sf_19.describe()
# Out:
#            Founded
# count    60.000000
# mean   2014.533333
# std       2.937003
# min    2004.000000
# 25%    2013.000000
# 50%    2015.000000
# 75%    2016.250000
# max    2019.000000

# %%
# explore to see data types of columns

# sf_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
# sf_19['Founded']
# Out:
# 0        NaN
# 1     2014.0
# 2        NaN
# 3     2014.0
# 4     2004.0
#        ...
# 84       NaN
# 85    2013.0
# 86    2016.0
# 87    2015.0
# 88       NaN
# Name: Founded, Length: 89, dtype: float64

# %%
# remove the dollar sign from Amount($)

# sf_19['Amount($)']= sf_19['Amount($)'].str.strip('$')
# sf_19
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# check data types

# sf_19.dtypes
# Out:
# Company/Brand     object
# Founded          float64
# HeadQuarter       object
# Sector            object
# What it does      object
# Founders          object
# Investor          object
# Amount($)         object
# Stage             object
# dtype: object

# %%
# change Amount($) data type from string to float

# sf_19['Amount($)']= sf_19['Amount($)'].astype(int)

# %%
# missing values
# sf_19.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# dtype: int64

# %%
# sf_19.isna().any()
# Out:
# Company/Brand    False
# Founded           True
# HeadQuarter       True
# Sector            True
# What it does     False
# Founders          True
# Investor         False
# Amount($)        False
# Stage             True
# dtype: bool
